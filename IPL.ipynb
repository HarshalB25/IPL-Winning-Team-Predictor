# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
delivery=pd.read_csv("C:\\Users\\Harshal Bhagat\\Downloads\\deliveries.csv")
match=pd.read_csv("C:\\Users\\Harshal Bhagat\\Downloads\\matches.csv")

# %%
delivery.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
match.head(10)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8   9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9  10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
delivery.describe()
match.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
delivery.shape
# Out:
# (179078, 21)

# %%
match.shape
# Out:
# (756, 18)

# %%
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
delivery.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
match.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(x=('Season'),
             data=match,
             order=match['Season'].value_counts().index.sort_values())
# Out:
# <AxesSubplot:xlabel='Season', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=('city'),
             data=match,
             order=match['city'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %%
plt.figure(figsize = (11,9))
sns.countplot(y = 'winner',
              data = match,
              order= match['winner'].value_counts().index,
              palette = 'cubehelix' )
# Out:
# <AxesSubplot:xlabel='count', ylabel='winner'>

# %%
plt.figure(figsize = (11,9))
sns.countplot(y = 'player_of_match',
              data = match,
              order= match['player_of_match'].value_counts().iloc[:15].index,
              palette = 'mako' )
# Out:
# <AxesSubplot:xlabel='count', ylabel='player_of_match'>

# %%
plt.figure(figsize = (11,9))
sns.countplot(y = 'toss_winner',
              data = match,
              order= match['toss_winner'].value_counts().iloc[:12].index,
              palette = 'magma' )
# Out:
# <AxesSubplot:xlabel='count', ylabel='toss_winner'>

# %%
plt.figure(figsize=(6,6))
sizes = match.toss_decision.value_counts()
labels = match.toss_decision.value_counts().index
plt.pie(sizes,colors = ['#ff9999','#66b3ff'],
         labels=labels,
         autopct='%1.1f%%',
         startangle=90,
         pctdistance=0.75,
         explode = (0.025,0.025))

#draw white circle
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              hue='toss_decision',
              data=match,
              order = match['Season'].value_counts().index.sort_values(),
              palette='deep')
plt.xlabel('Season',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Decision to field or bat in each IPL season', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Decision to field or bat in each IPL season')

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
match=match[match['dl_applied']==0]

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 737 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               737 non-null    int64
#  1   Season           737 non-null    object
#  2   city             730 non-null    object
#  3   date             737 non-null    object
#  4   team1            737 non-null    object
#  5   team2            737 non-null    object
#  6   toss_winner      737 non-null    object
#  7   toss_decision    737 non-null    object
#  8   result           737 non-null    object
#  9   dl_applied       737 non-null    int64
#  10  winner           733 non-null    object
#  11  win_by_runs      737 non-null    int64
#  12  win_by_wickets   737 non-null    int64
#  13  player_of_match  733 non-null    object
#  14  venue            737 non-null    object
#  15  umpire1          735 non-null    object
#  16  umpire2          735 non-null    object
# ...

# %%
match_df=match[['id','city','toss_winner','toss_decision','winner','result']]

# %%
match_df
# Out:
#         id           city                  toss_winner toss_decision  \
# 0        1      Hyderabad  Royal Challengers Bangalore         field
# 1        2           Pune       Rising Pune Supergiant         field
# 2        3         Rajkot        Kolkata Knight Riders         field
# 3        4         Indore              Kings XI Punjab         field
# 4        5      Bangalore  Royal Challengers Bangalore           bat
# ..     ...            ...                          ...           ...
# 751  11347         Mumbai               Mumbai Indians         field
# 752  11412        Chennai          Chennai Super Kings           bat
# 753  11413  Visakhapatnam               Delhi Capitals         field
# 754  11414  Visakhapatnam          Chennai Super Kings         field
# 755  11415      Hyderabad               Mumbai Indians           bat
#
#                           winner  result
# 0            Sunrisers Hyderabad  normal
# 1         Rising Pune Supergiant  normal
# ...

# %%
delivery_df=delivery[['match_id','inning','batting_team','bowling_team','over','ball','total_runs','player_dismissed']]

# %%
delivery_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
#         over  ball  total_runs player_dismissed
# ...

# %%
delivery_df['balls_remaining']=120-(delivery_df['ball'])
# Out:
# C:\Users\HARSHA~1\AppData\Local\Temp/ipykernel_6496/355425040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_remaining']=120-(delivery_df['ball'])

# %%
total_score=delivery_df.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
match_df=match_df.merge(total_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#          id           city                  toss_winner toss_decision  \
# 0         1      Hyderabad  Royal Challengers Bangalore         field
# 1         1      Hyderabad  Royal Challengers Bangalore         field
# 2         2           Pune       Rising Pune Supergiant         field
# 3         2           Pune       Rising Pune Supergiant         field
# 4         3         Rajkot        Kolkata Knight Riders         field
# ...     ...            ...                          ...           ...
# 1485  11413  Visakhapatnam               Delhi Capitals         field
# 1486  11414  Visakhapatnam          Chennai Super Kings         field
# 1487  11414  Visakhapatnam          Chennai Super Kings         field
# 1488  11415      Hyderabad               Mumbai Indians           bat
# 1489  11415      Hyderabad               Mumbai Indians           bat
#
#                       winner  result  match_id  total_runs
# 0        Sunrisers Hyderabad  normal         1         207
# ...

# %%
total_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
delivery_df['batting_team']=delivery_df['batting_team'].str.replace('Pune Warriors','Rising Pune Supergiant')
delivery_df['bowling_team']=delivery_df['bowling_team'].str.replace('Pune Warriors','Rising Pune Supergiant')

delivery_df['batting_team']=delivery_df['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['bowling_team']=delivery_df['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')

delivery_df['batting_team']=delivery_df['batting_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['bowling_team']=delivery_df['bowling_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
# Out:
# C:\Users\HARSHA~1\AppData\Local\Temp/ipykernel_6496/2761035960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['batting_team']=delivery_df['batting_team'].str.replace('Pune Warriors','Rising Pune Supergiant')
# C:\Users\HARSHA~1\AppData\Local\Temp/ipykernel_6496/2761035960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['bowling_team']=delivery_df['bowling_team'].str.replace('Pune Warriors','Rising Pune Supergiant')
# ...

# %%
delivery_df.shape
# Out:
# (179078, 9)

# %%
delivery['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams=['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
       'Mumbai Indians', 'Rising Pune Supergiant','Kolkata Knight Riders', 'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals', 'Rising Pune Supergiants',
       'Delhi Capitals'
    
]

# %%
delivery_df=delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df=delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# total_runs               0
# player_dismissed    160436
# balls_remaining          0
# dtype: int64

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna('0')

# %%
delivery_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
#         over  ball  total_runs player_dismissed  balls_remaining
# ...

# %%
match_df.isnull().sum()
# Out:
# id                0
# city             14
# toss_winner       0
# toss_decision     0
# winner            6
# result            0
# match_id          0
# total_runs        0
# dtype: int64

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
#         over  ball  total_runs player_dismissed  balls_remaining
# ...

# %%
final_df=delivery_df.merge(match_df[['id','toss_winner','toss_decision','city','total_runs','winner','result']],left_on='match_id',right_on='id')

# %%
final_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 335464     11415       2  Chennai Super Kings               Mumbai Indians
# 335465     11415       2  Chennai Super Kings               Mumbai Indians
# 335466     11415       2  Chennai Super Kings               Mumbai Indians
# 335467     11415       2  Chennai Super Kings               Mumbai Indians
# 335468     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
delivery_df['wickets'] = 10 - wickets
delivery_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball  total_runs  player_dismissed  balls_remaining  wickets
# 0     1           0                 0              119       10
# 1     2           0                 0              118       10
# 2     3           4                 0              117       10
# 3     4           0                 0              116       10
# 4     5           2                 0              115       10

# %%
final_df['result'] = final_df.apply(result,axis=1)

# %%
final_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 335464     11415       2  Chennai Super Kings               Mumbai Indians
# 335465     11415       2  Chennai Super Kings               Mumbai Indians
# 335466     11415       2  Chennai Super Kings               Mumbai Indians
# 335467     11415       2  Chennai Super Kings               Mumbai Indians
# 335468     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
final_df.isnull().sum()
# Out:
# match_id               0
# inning                 0
# batting_team           0
# bowling_team           0
# over                   0
# ball                   0
# total_runs_x           0
# player_dismissed       0
# balls_remaining        0
# id                     0
# toss_winner            0
# toss_decision          0
# city                3400
# total_runs_y           0
# winner               553
# result                 0
# dtype: int64

# %%
final_df.dropna()
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 335464     11415       2  Chennai Super Kings               Mumbai Indians
# 335465     11415       2  Chennai Super Kings               Mumbai Indians
# 335466     11415       2  Chennai Super Kings               Mumbai Indians
# 335467     11415       2  Chennai Super Kings               Mumbai Indians
# 335468     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335469 entries, 0 to 335468
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          335469 non-null  int64
#  1   inning            335469 non-null  int64
#  2   batting_team      335469 non-null  object
#  3   bowling_team      335469 non-null  object
#  4   over              335469 non-null  int64
#  5   ball              335469 non-null  int64
#  6   total_runs_x      335469 non-null  int64
#  7   player_dismissed  335469 non-null  object
#  8   balls_remaining   335469 non-null  int64
#  9   id                335469 non-null  int64
#  10  toss_winner       335469 non-null  object
#  11  toss_decision     335469 non-null  object
#  12  city              332069 non-null  object
#  13  total_runs_y      335469 non-null  int64
#  14  winner            334916 non-null  object
#  15  result            335469 non-null  int64
# ...

# %%
final_df.isnull().sum()
# Out:
# match_id               0
# inning                 0
# batting_team           0
# bowling_team           0
# over                   0
# ball                   0
# total_runs_x           0
# player_dismissed       0
# balls_remaining        0
# id                     0
# toss_winner            0
# toss_decision          0
# city                3400
# total_runs_y           0
# winner               553
# result                 0
# dtype: int64

# %%
final_df['toss_decision']=final_df['toss_decision'].replace('bat',1,inplace=True)
final_df['toss_decision'][final_df['toss_decision'] != 1] = 0
# Out:
# C:\Users\HARSHA~1\AppData\Local\Temp/ipykernel_6496/1753477069.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['toss_decision'][final_df['toss_decision'] != 1] = 0

# %%
final_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 335464     11415       2  Chennai Super Kings               Mumbai Indians
# 335465     11415       2  Chennai Super Kings               Mumbai Indians
# 335466     11415       2  Chennai Super Kings               Mumbai Indians
# 335467     11415       2  Chennai Super Kings               Mumbai Indians
# 335468     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335469 entries, 0 to 335468
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          335469 non-null  int64
#  1   inning            335469 non-null  int64
#  2   batting_team      335469 non-null  object
#  3   bowling_team      335469 non-null  object
#  4   over              335469 non-null  int64
#  5   ball              335469 non-null  int64
#  6   total_runs_x      335469 non-null  int64
#  7   player_dismissed  335469 non-null  object
#  8   balls_remaining   335469 non-null  int64
#  9   id                335469 non-null  int64
#  10  toss_winner       335469 non-null  object
#  11  toss_decision     335469 non-null  object
#  12  city              332069 non-null  object
#  13  total_runs_y      335469 non-null  int64
#  14  winner            334916 non-null  object
#  15  result            335469 non-null  int64
# ...

# %%
final_df=final_df[['batting_team','bowling_team','toss_winner','city','inning','over','balls_remaining','toss_decision','total_runs_y','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                batting_team      bowling_team       toss_winner       city  \
# 103949  Sunrisers Hyderabad  Rajasthan Royals  Rajasthan Royals  Hyderabad
#
#         inning  over  balls_remaining toss_decision  total_runs_y  result
# 103949       1     6              115             0           141       0

# %%
final_df.dropna(inplace=True)

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','toss_winner','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team',
#                                                    'toss_winner', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.649275755111874

# %%
pipe.predict_proba(X_test)[51511]

# %%
pipe2 = Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
pipe2.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\HARSHA~1\AppData\Local\Temp/ipykernel_6496/2994767042.py in <module>
# ----> 1 pipe2.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
# ...

# %%
y_pred1 = pipe2.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)

# %%
pipe2.predict_proba(X_test)[51511]

# %%
teams

# %%
final_df['city'].unique()

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
